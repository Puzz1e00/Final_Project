# %%
import pandas as pd
df = pd.read_csv("share.csv")
df
# Out:
#      S.N BUSINESS_DATE  SECURITY_ID  SYMBOL  \
# 0      1    2023-03-20          133     SCB
# 1      2    2023-03-20          179     HEI
# 2      3    2023-03-20          358    LBBL
# 3      4    2023-03-20          559     NLG
# 4      5    2023-03-20          634  RBCLPO
# ..   ...           ...          ...     ...
# 207  208    2023-03-20         8032    BNHC
# 208  209    2023-03-20         8045     GVL
# 209  210    2023-03-20         8073   NICFC
# 210  211    2023-03-20         8100    SGHC
# 211  212    2023-03-20         8123    DLBS
#
#                                      SECURITY_NAME  OPEN_PRICE  HIGH_PRICE  \
# 0                  Standard Chartered Bank Limited      521.00       521.0
# 1              Himalayan Everest Insurance Limited      420.00       420.0
# 2                          Lumbini Bikas Bank Ltd.      335.00       335.0
# 3                       NLG Insurance Company Ltd.      649.10       684.0
# ...

# %%
#df = pd.read_csv("share.csv",nrows=5)
df = pd.read_csv("share.csv",skiprows=2,nrows=5)
df
df.to_csv("new-stock.csv")

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7]
y = [50,51,52,78,42,20,21]
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot(x,y)

# %%
plt.plot(x,y, '--rD')

# %%
days = [1,2,3,4]
max_t = [50,51,52,48]
min_t = [7,12,15,20]
avg = [35,30,45,33]
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot(days, max_t, label='Max')
plt.plot(days, avg, label= 'Min')
plt.plot(days, avg, label= 'Avg')
plt.legend(loc = "best")
plt.grid()
